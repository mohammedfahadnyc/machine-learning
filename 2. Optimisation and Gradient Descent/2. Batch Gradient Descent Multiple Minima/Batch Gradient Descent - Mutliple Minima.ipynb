# %% [markdown]
# ## Example 2 -Gradient Discent with Multiple Minima
# Functiion $$ g(x) = x^4 - 4x^2 + 5 $$

# %%
import numpy as np

x_2 = np.linspace(-2,2,1000)
def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %% [markdown]
# ## Plot Cost Function

# %%
import matplotlib.pyplot as plt
# Chart 1 - Cost Function Visualising with showing how gradient descent moved our new_x across the plot 
# (new_x and the costwhich is f(new_x), both moved actually and we visualize that)
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Cost Funtion")
plt.plot(x_2,g(x_2),color='blue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(0.5,5.5)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize=16)


#showing gradient descent in the cost function
# plt.scatter(new_x_list,f(np.array(new_x_list)),color='red',s=100,alpha=0.6)





# Chart 2 - Showing how our x_1 and its gradients and how the gradient descent algo moved our x_1 and gradients in this
# plot
plt.subplot(1,2,2)
plt.title("Slope of the Cost Function ")
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.xlabel('X', fontsize = 16)
plt.grid()
plt.ylabel('Dg(x)', fontsize=16)

#showing gradient descent in the slope chart
# plt.scatter(new_x_list,dg(np.array(new_x_list)),color='red',s=100,alpha=0.6)
# Out:
# Text(0, 0.5, 'Dg(x)')

# %% [markdown]
# ### Gradient Descent as a python function
# #### args: derivative(cost) function, initial guess, steps_multiplier or learning rate,  precision, max_iter
# #### returns : new_x (minima), new_x_list, slopes_list

# %%
# Gradient Descent Algorithm

def gradient_descent(derivative_function,initial_guess,steps_multiplier,precision,max_iter=300):
    new_x = initial_guess
    new_x_list = [new_x]
    slopes_list = [derivative_function(new_x)]
    
    #The main algorithm
    for _ in range(max_iter):
        prev_x = new_x
        gradient = derivative_function(prev_x)
        new_x = prev_x - (gradient*steps_multiplier)
        new_x_list.append(new_x)
        slopes_list.append(derivative_function(new_x))
        step_size = abs(prev_x - new_x)
        if step_size < precision:
            break
    return new_x,new_x_list,slopes_list

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg,initial_guess=0.5,steps_multiplier=0.02,precision=0.001)
print(local_min,list_x,deriv_list)
print(f"Steps taken is {len(list_x)}")
# Out:
# 1.4122375085019094 [0.5, 0.5700000000000001, 0.6463845600000001, 0.7282006598573135, 0.8138209670755288, 0.9009125343861493, 0.9865609632751697, 1.067592934538704, 1.141064281109816, 1.204778782550515, 1.257645254790938, 1.2997339542854778, 1.3320392730310104, 1.356087523785901, 1.3735568198659485, 1.3860113169570543, 1.3947678735885645, 1.4008627390357724, 1.4050746946966322, 1.407970846159076, 1.4099553074429387, 1.411311800743334, 1.4122375085019094] [-3.5, -3.8192280000000003, -4.090804992865673, -4.28101536091076, -4.354578365531026, -4.282421444451021, -4.051598563176713, -3.6735673285555963, -3.1857250720349457, -2.6433236120211516, -2.104434974726992, -1.6152659372766287, -1.202412537744527, -0.873464804002376, -0.6227248545552868, -0.4378278315755093, -0.3047432723604011, -0.21059778304298504, -0.14480757312219872, -0.09922306419313287, -0.06782466501976359, -0.04628538792876746, -0.03155062633818417]
# Steps taken is 23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg,initial_guess=-0.5,steps_multiplier=0.02,precision=0.001)
print(local_min,list_x,deriv_list)
print(f"Steps taken is {len(list_x)}")
# Out:
# -1.4122375085019094 [-0.5, -0.5700000000000001, -0.6463845600000001, -0.7282006598573135, -0.8138209670755288, -0.9009125343861493, -0.9865609632751697, -1.067592934538704, -1.141064281109816, -1.204778782550515, -1.257645254790938, -1.2997339542854778, -1.3320392730310104, -1.356087523785901, -1.3735568198659485, -1.3860113169570543, -1.3947678735885645, -1.4008627390357724, -1.4050746946966322, -1.407970846159076, -1.4099553074429387, -1.411311800743334, -1.4122375085019094] [3.5, 3.8192280000000003, 4.090804992865673, 4.28101536091076, 4.354578365531026, 4.282421444451021, 4.051598563176713, 3.6735673285555963, 3.1857250720349457, 2.6433236120211516, 2.104434974726992, 1.6152659372766287, 1.202412537744527, 0.873464804002376, 0.6227248545552868, 0.4378278315755093, 0.3047432723604011, 0.21059778304298504, 0.14480757312219872, 0.09922306419313287, 0.06782466501976359, 0.04628538792876746, 0.03155062633818417]
# Steps taken is 23

# %% [markdown]
# ## Calling the gradient descent algo

# %%
# Starting value is 0.1

#calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg,initial_guess=0.1,steps_multiplier=0.02,precision=0.001)
#Plot function and derivative scatterplot side by side
#1. Chart : Cost function

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Cost Funtion")
plt.plot(x_2,g(x_2),color='blue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(0.5,5.5)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize=16)


#showing gradient descent in the cost function
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)





# Chart 2 - Showing how our x_1 and its gradients and how the gradient descent algo moved our x_1 and gradients in this
# plot
plt.subplot(1,2,2)
plt.title("Slope of the Cost Function ")
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.xlabel('X', fontsize = 16)
plt.grid()
plt.ylabel('Dg(x)', fontsize=16)

#showing gradient descent in the slope chart
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.6)

# plt.scatter(list_x,dg(np.array(list_x)),color='red',s=100,alpha=0.6)

# %%
# Starting value is 0

#calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg,initial_guess=0,steps_multiplier=0.02,precision=0.001)
#Plot function and derivative scatterplot side by side
#1. Chart : Cost function

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Cost Funtion")
plt.plot(x_2,g(x_2),color='blue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(0.5,5.5)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize=16)


#showing gradient descent in the cost function
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)





# Chart 2 - Showing how our x_1 and its gradients and how the gradient descent algo moved our x_1 and gradients in this
# plot
plt.subplot(1,2,2)
plt.title("Slope of the Cost Function ")
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.xlabel('X', fontsize = 16)
plt.grid()
plt.ylabel('Dg(x)', fontsize=16)

#showing gradient descent in the slope chart
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.6)

# plt.scatter(list_x,dg(np.array(list_x)),color='red',s=100,alpha=0.6)

# %%
# Starting value is 0

#calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg,initial_guess=-0.2,steps_multiplier=0.02,precision=0.001)
#Plot function and derivative scatterplot side by side
#1. Chart : Cost function

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.title("Cost Funtion")
plt.plot(x_2,g(x_2),color='blue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(0.5,5.5)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize=16)


#showing gradient descent in the cost function
plt.scatter(list_x,g(np.array(list_x)),color='red',s=100,alpha=0.6)





# Chart 2 - Showing how our x_1 and its gradients and how the gradient descent algo moved our x_1 and gradients in this
# plot
plt.subplot(1,2,2)
plt.title("Slope of the Cost Function ")
plt.plot(x_2,dg(x_2),color='skyblue',linewidth=3)
plt.xlim(-2,2)
plt.ylim(-6,8)
plt.xlabel('X', fontsize = 16)
plt.grid()
plt.ylabel('Dg(x)', fontsize=16)

#showing gradient descent in the slope chart
plt.scatter(list_x,deriv_list,color='red',s=100,alpha=0.6)

# plt.scatter(list_x,dg(np.array(list_x)),color='red',s=100,alpha=0.6)

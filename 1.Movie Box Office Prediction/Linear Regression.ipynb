# %% [markdown]
# Note : We have a feature x (input) and a label y (we are trying to predict), our regression model will create this line of best fit with y values. Our data has one feature (single variable) and one label ( we are trying to predict one thing)

# %% [markdown]
# ### 1. Create Dataframe (X,Y) using pandas  2.Create a plot using matplotlib                                                          3.Create regression model using sklearn

# %%
# All Libraries Needed For Regression
# import pandas
# from pandas import DataFrame
# import matplotlib
# from matplotlib import pyplot
# import sklearn
# from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 1. Creating X,Y (Dataframe) Using Pandas

# %%
import pandas
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data
# Out:
#       production_budget_usd  worldwide_gross_usd
# 0                   1000000                   26
# 1                     10000                  401
# 2                    400000                  423
# 3                    750000                  450
# 4                     10000                  527
# ...                     ...                  ...
# 5029              225000000           1519479547
# 5030              215000000           1671640593
# 5031              306000000           2058662225
# 5032              200000000           2207615668
# 5033              425000000           2783918982
#
# [5034 rows x 2 columns]

# %%
data.describe()    #finding mean,median etc
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
from pandas import DataFrame
X = DataFrame(data,columns=['production_budget_usd'])

# %%
Y = DataFrame(data,columns=['worldwide_gross_usd'])

# %%
X,Y
# Out:
# (      production_budget_usd
#  0                   1000000
#  1                     10000
#  2                    400000
#  3                    750000
#  4                     10000
#  ...                     ...
#  5029              225000000
#  5030              215000000
#  5031              306000000
#  5032              200000000
#  5033              425000000
#
#  [5034 rows x 1 columns],
#        worldwide_gross_usd
#  0                      26
#  1                     401
#  2                     423
#  3                     450
#  4                     527
#  ...                   ...
#  5029           1519479547
#  5030           1671640593
#  5031           2058662225
#  5032           2207615668
#  5033           2783918982
#
#  [5034 rows x 1 columns])

# %% [markdown]
# ## 2. Plotting using matplotlib

# %%
#Plotting using matplotlib
from matplotlib import pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3)
plt.title("Budget vs Revenue")
plt.xlabel("Budget")
plt.ylabel("Revenue")
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# ## 3. Creating Regression Model

# %%
#Creating the regression model
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X,Y)
regression.coef_, regression.intercept_
# Out:
# (array([[3.11150918]]), array([-7236192.72913958]))

# %%
# Out:
# array([-7236192.72913958])

# %%
#Creating the line of best fit
plt.figure(figsize=(10,6))
plt.scatter(X,Y,alpha=0.3)
plt.title("Budget vs Revenue")
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.plot(X,regression.predict(X),color='red',linewidth=3)
plt.show()

# %%
#Eavluating the model, note: We are evaluating using the data we used to train the model, we should also test on new data
regression.score(X,Y)
# Out:
# 0.5496485356985729
